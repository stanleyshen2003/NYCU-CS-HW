# %% [markdown]
# clone & install requirements

# %%
# !git clone https://github.com/stanleyshen2003/FGVC.git
# %cd FGVC
# !pip install -r requirements.txt
# Out:
# Cloning into 'FGVC'...
# remote: Enumerating objects: 13282, done.
# remote: Counting objects: 100% (1285/1285), done.
# remote: Compressing objects: 100% (1033/1033), done.
# remote: Total 13282 (delta 366), reused 1150 (delta 234), pack-reused 11997
# Receiving objects: 100% (13282/13282), 352.88 MiB | 30.65 MiB/s, done.
# Resolving deltas: 100% (367/367), done.
# Updating files: 100% (12342/12342), done.
# /content/FGVC
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/670.2 MB 77.2 MB/s eta 0:00:08
# ERROR: Operation cancelled by user

# %% [markdown]
# put model https://drive.google.com/file/d/1f1nFf7kIOaqOSioaS0huAYU_cXPC2ZDQ/view?usp=sharing at FGVC/record/FGVC-HERBS2/basline/backup/best.pt
#
# put model https://drive.google.com/file/d/1mBD9kySQl_MdVKftQfZFGZS-ocCUiL-a/view?usp=sharing at FGVC/record/FGVC-HERBS_no_amp/basline/backup/best.pt
#
# put model https://drive.google.com/file/d/1y26e-QilU4KV9CwuSc2ZK6QHZ_Fd9UCA/view?usp=sharing at FGVC/record/FGVC-HERBS2_model/basline/backup/best.pt
#
# (they have the same name, so you can only put them one by one...)
#
# (or just download this https://drive.google.com/drive/folders/1SuppCf4XBS7yMQtflvcs9idpJcXTCjnq?usp=drive_link)

# %% [markdown]
# Get the predictions from the three models. The numbers are progress, but they output all at once since it is a terminal output.

# %%
# !echo "first model"
# !python for_judge.py -ir ./bird_data/test/all_test -pr records/FGVC-HERBS2/basline -csv submission_normal.csv
# !echo -e "\nsecond model"
# !python for_judge.py -ir ./bird_data/test/all_test -pr records/FGVC-HERBS2_model/basline -csv submission_model.csv
# !echo -e "\nthird model"
# !python for_judge.py -ir ./bird_data/test/all_test -pr records/FGVC-HERBS_no_amp/basline -csv submission_amp.csv
# Out:
# first model
# 32...64...96...128...160...192...224...256...288...320...352...384...416...448...480...512...544...576...608...640...672...704...736...768...800...832...864...896...928...960...992...1024...1056...1088...1120...1152...1184...1216...1248...1280...1312...1344...1376...1408...1440...1472...1504...1536...1568...1600...1632...1664...1696...1728...1760...1792...1824...1856...1888...1920...1952...1984...2000...
# second model
# 32...64...96...128...160...192...224...256...288...320...352...384...416...448...480...512...544...576...608...640...672...704...736...768...800...832...864...896...928...960...992...1024...1056...1088...1120...1152...1184...1216...1248...1280...1312...1344...1376...1408...1440...1472...1504...1536...1568...1600...1632...1664...1696...1728...1760...1792...1824...1856...1888...1920...1952...1984...2000...
# third model
# ...

# %% [markdown]
# merge the prediction of the three model

# %%
# !python merge_predicts.py
# !rm submission_*.csv
# Out:
# merge completed, result in submission.csv
